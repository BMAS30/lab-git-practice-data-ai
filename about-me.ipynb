# %% [markdown]
# ## About Me Lab: AI Engineering, Data Analytics & Data Science
#
# In this notebook, you'll write a short introduction about yourself using Python!
#
# ### Instructions:
# - Fill in the variables below with your details.
# - Run the cell to print your introduction.
#
# ### What to Include:
# - Your name.
# - Why you're interested in AI Engineering, Data Analytics or Data Science.
# - A fun fact about yourself or a goal for this course.

# %%
# About Me
# Please fill in the following details.

name = "Bruno Sousa"
reason = "I like to uncover patterns that are invisible to most people, and by doing so, if I can solve a problem, even better!  "
goals = "get the knowlege needed so I can thrive in my new upcoming job"

print(f"Hi! My name is {name}. I’m excited to learn because {reason}. My goal is: {goals}.")
# Out:
# Hi! My name is Bruno Sousa. I’m excited to learn because I like to uncover patterns that are invisible to most people, and by doing so, if I can solve a problem, even better!  . My goal is: get the knowlege needed so I can thrive in my new upcoming job.
